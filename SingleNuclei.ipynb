# %%
import numpy as np
import matplotlib.pyplot as plt

from Single_nuclei_segmentation import Solv, segmented
from generate_fragments import generate_fragments

# %%
image = plt.imread('../images/nuclei_000.png')
#Omega, S = generate_fragments(image,16,0.01,20,2,100)
coords = [(i,j) for i in range(image.shape[0]) for j in range(image.shape[1])]
theta = Solv(image, coords)[0]
segmentation = segmented(image,theta,20)
plt.imshow(segmentation)
plt.colorbar()
plt.show()
